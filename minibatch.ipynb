# %% [markdown]
# <a href="https://colab.research.google.com/github/yash-316/Unsupervised-Machine-Learning/blob/main/minibatch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.cluster import MiniBatchKMeans
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# %%
X, Y= make_blobs(n_samples=600,centers=3, n_features=5, random_state=42)

# %%
mbk_means = MiniBatchKMeans(n_clusters=5, batch_size=200,random_state=42)

# %%
mbk_means.fit(X)
# Out:
# MiniBatchKMeans(batch_size=200, n_clusters=5, random_state=42)

# %%
plt.scatter(X[:,0],X[:,1], c=mbk_means.labels_,cmap='viridis')

# %%
plt.scatter(mbk_means.cluster_centers_[:, 0], mbk_means.cluster_centers_[:, 1],s=200,c='red',marker='X')

# %%
plt.title('MiniBatchKMeans')
plt.show()
