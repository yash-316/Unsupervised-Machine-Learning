# %% [markdown]
# <a href="https://colab.research.google.com/github/yash-316/Unsupervised-Machine-Learning/blob/main/AgglomerativeClustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import linkage, dendrogram
from sklearn.metrics import davies_bouldin_score

# %%
X, _ = make_blobs(
    n_samples=30,
    centers=3,
    random_state=42
)

# Agglomerative clustering
label = AgglomerativeClustering(
    n_clusters=3,
    linkage='single'
).fit_predict(X)

# Davies-Bouldin score
score = davies_bouldin_score(X, label)

print("Davies-Bouldin Score:", score)

# Plot 1: Dendrogram
plt.subplot(1, 2, 1)
dendrogram(linkage(X, 'single'))
plt.title("Dendrogram")

# Plot 2: Clusters
plt.subplot(1, 2, 2)
plt.scatter(X[:, 0], X[:, 1], c=label)
plt.title("Agglomerative Clustering")

plt.show()
# Out:
# Davies-Bouldin Score: 0.21271389410473407
